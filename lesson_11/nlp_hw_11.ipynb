# %% [markdown]
# <a href="https://colab.research.google.com/github/dave502/NLP/blob/main/lesson_11/nlp_hw_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split
import numpy as np

import unicodedata
import re
import os
import io
from pathlib import Path

# %% [markdown]
# Загрузка данных

# %%
# %%capture
# !wget http://www.manythings.org/anki/rus-eng.zip
# !rm ru_en -r
# !mkdir ru_en
# !unzip rus-eng.zip -d ru_en
# !rm rus-eng.zip

# %%
# !ls ru_en
# Out:
# _about.txt  rus.txt

# %%
data_path = Path('/content/ru_en/rus.txt')

# %% [markdown]
# Функция предобработки текста

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-ЯЁё~?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("This is example sentence.")
# Out:
# '<start> this is example sentence . <end>'

# %% [markdown]
# Функции создания и токенизации датасета

# %%
def create_dataset(data_path: Path, num_examples: int) -> zip:
  lines = data_path.read_text(encoding='UTF-8').strip().split('\n')

  word_pairs = [[preprocess_sentence(sent) for sent in line.split('\t')[:2]] for line in lines[:num_examples]]

  return zip(*word_pairs)

def load_dataset(data_path: Path, num_examples: int) -> tuple:
  # creating cleaned input, output pairs
  target_lang, input_lang = create_dataset(data_path, num_examples)

  input_tensor, input_lang_tokenizer = tokenize(input_lang)
  target_tensor, target_lang_tokenizer = tokenize(target_lang)

  return input_tensor, target_tensor, input_lang_tokenizer, target_lang_tokenizer

def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post')

  return tensor, lang_tokenizer

# %% [markdown]
# Проверка создания датасета

# %%
en, ru = create_dataset(data_path, None)
print(f'len(en) = {len(en)}, len(ru) = {len(ru)}')
print(en[-1])
print(ru[-1])
# Out:
# len(en) = 451436, len(ru) = 451436
# <start> doubtless there exists in this world precisely the right woman for any given man to marry and vice versa but when you consider that a human being has the opportunity of being acquainted with only a few hundred people , and out of the few hundred that there are but a dozen or less whom he knows intimately , and out of the dozen , one or two friends at most , it will easily be seen , when we remember the number of millions who inhabit this world , that probably , since the earth was created , the right man has never yet met the right woman . <end>
# <start> несомненно , для каждого мужчины в этом мире где то есть подходящая женщина , которая может стать ему женой , обратное верно и для женщин . но если учесть , что у человека может быть максимум несколько сотен знакомых , из которых лишь дюжина , а то и меньше , тех , кого он знает близко , а из этой дюжины у него один или от силы два друга , то можно легко увидеть , что с учётом миллионов живущих на земле людей , ни один подходящий мужчина , возможно , ещё не встретил подходящую женщину . <end>

# %% [markdown]
# Загрузка датасета из файла (в виде массивов), получение токенайзеров

# %%
NUM_EXAMPLES = 100000
input_tensor, target_tensor, input_lang_tokenizer, target_lang_tokenizer = load_dataset(data_path, NUM_EXAMPLES)

# %% [markdown]
# Длины полученных тензоров

# %%
# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]
max_length_targ, max_length_inp
# Out:
# (11, 15)

# %% [markdown]
# Разбиение датасета на обучающий и валидационный (массивы)

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %% [markdown]
# Проверка работы токенайзеров для вхоящих и целевых тензоров

# %%
def show_mapping(tokenizer, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, tokenizer.index_word[t]))

print ("Input Language; index to word mapping")
show_mapping(input_lang_tokenizer, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
show_mapping(target_lang_tokenizer, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 4 ----> я
# 98 ----> их
# 1821 ----> отпустил
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 4 ----> i
# 86 ----> let
# 96 ----> them
# 27 ----> go
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# Параметры модели

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
STEPS_PER_EPOCH = len(input_tensor_train)//BATCH_SIZE
EMBEDDING_DIM = 300
UNITS = 1024
WITH_ATTENTION = True
vocab_inp_size = len(input_lang_tokenizer.word_index)+1
vocab_tar_size = len(target_lang_tokenizer.word_index)+1

# %% [markdown]
# Преобразование датасетов из массивов в tf тензор

# %%
dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# Проверка размеров полученного тензора ([<размер батча>, <длина строки данных>])

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %% [markdown]
# Класс энкодера. На выходе - состояние ячеек GRU и слоя GRU.

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, rnn_units, batch_size, with_attention=True):
        super(Encoder, self).__init__()

        self.batch_size = batch_size
        self.rnn_units = rnn_units
        self.with_attention = with_attention

        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.rnn_units, return_sequences=with_attention, return_state=True, recurrent_initializer='glorot_uniform')

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state=hidden)
        return output, state

    def get_zero_hidden_state(self):
        return tf.zeros((self.batch_size, self.rnn_units))

# %%
encoder = Encoder(vocab_inp_size, EMBEDDING_DIM, UNITS, BATCH_SIZE, with_attention=WITH_ATTENTION)

# %% [markdown]
# Проверка работы энкодера. На выходе - (<размер батча>, <количество GRU ячеек>)

# %%
# sample input
sample_hidden = encoder.get_zero_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 15, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 15, 1)

# %% [markdown]
# Класс декодера. На входе данные и состояние энкодера, на выходе - вероятностное распределение словаря + состояние gru декодера

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, rnn_units, batch_size, with_attention=True):
        super(Decoder, self).__init__()

        self.batch_size = batch_size
        self.rnn_units = rnn_units
        self.with_attention = with_attention
        
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.rnn_units, return_sequences=True, return_state=True, recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)
        # used for attention
        self.attention = BahdanauAttention(self.rnn_units)

    def call(self, x, hidden, enc_output=None):
        attention_weights = None

        x = self.embedding(x) # x shape after passing through embedding == (batch_size, 1, embedding_dim)

        if self.with_attention:
          context_vector, attention_weights = self.attention(hidden, enc_output)
          # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
          x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)
          output, state = self.gru(x)
        else:
          output, state = self.gru(x, initial_state=hidden)

        output = tf.reshape(output, (-1, output.shape[2])) # output shape == (batch_size * 1, hidden_size)
        x = self.fc(output) # output shape == (batch_size, vocab)

        return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, EMBEDDING_DIM, UNITS, BATCH_SIZE, with_attention=WITH_ATTENTION)

# %% [markdown]
# Проверка работы декодера

# %%
sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)
print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 7335)

# %% [markdown]
# Оптимизатор и лосс-функция для модели

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_funcion(real, pred):
    
    loss_ = loss_object(real, pred)

    mask = tf.math.logical_not(tf.math.equal(real, 0))
    mask = tf.cast(mask, dtype=loss_.dtype)

    loss_ *= mask

    return tf.reduce_mean(loss_)

# %% [markdown]
# Функция шага обучения энкодера, декодера

# %%
@tf.function
def train_step(input, target, encoder_hidden):
    loss = 0
    enc_output = None

    with tf.GradientTape() as tape:
        enc_output, encoder_hidden = encoder(input, encoder_hidden)

        decoder_hidden = encoder_hidden

        decoder_input = tf.expand_dims([target_lang_tokenizer.word_index['<start>']] * BATCH_SIZE, 1)

        # Teacher forcing - feeding the target as the next input
        for t in range(1, target.shape[1]):
            # passing enc_output to the decoder
            predictions, decoder_hidden, _ = decoder(decoder_input, decoder_hidden, enc_output)

            loss += loss_funcion(target[:, t], predictions)

            # using teacher forcing
            decoder_input = tf.expand_dims(target[:, t], 1)

    batch_loss = (loss / int(target.shape[1]))

    variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, variables)

    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %% [markdown]
# Обучение энкодера, декодера

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
    
    encoder_hidden = encoder.get_zero_hidden_state()
    total_loss = 0

    for (batch, (input, target)) in enumerate(dataset.take(STEPS_PER_EPOCH)):
      batch_loss = train_step(input, target, encoder_hidden)
      total_loss += batch_loss

      if batch % 100 == 0: print(f'Epoch {epoch+1} Batch {batch} Loss {batch_loss:.4f}')

    print(f'Epoch {epoch+1} Batch {batch} Loss {total_loss / STEPS_PER_EPOCH:.4f}')
# Out:
# Epoch 1 Batch 0 Loss 4.5012
# Epoch 1 Batch 100 Loss 2.2683
# Epoch 1 Batch 200 Loss 1.6499
# Epoch 1 Batch 300 Loss 1.6473
# Epoch 1 Batch 400 Loss 1.5034
# Epoch 1 Batch 500 Loss 1.3901
# Epoch 1 Batch 600 Loss 1.3924
# Epoch 1 Batch 700 Loss 1.3597
# Epoch 1 Batch 800 Loss 1.2035
# Epoch 1 Batch 900 Loss 1.1443
# Epoch 1 Batch 1000 Loss 1.0529
# Epoch 1 Batch 1100 Loss 0.9927
# Epoch 1 Batch 1200 Loss 1.0485
# Epoch 1 Batch 1249 Loss 1.4171
# Epoch 2 Batch 0 Loss 0.8382
# Epoch 2 Batch 100 Loss 0.7729
# Epoch 2 Batch 200 Loss 0.7134
# Epoch 2 Batch 300 Loss 0.7545
# Epoch 2 Batch 400 Loss 0.6419
# Epoch 2 Batch 500 Loss 0.5876
# Epoch 2 Batch 600 Loss 0.6515
# Epoch 2 Batch 700 Loss 0.5358
# Epoch 2 Batch 800 Loss 0.6064
# Epoch 2 Batch 900 Loss 0.5634
# Epoch 2 Batch 1000 Loss 0.4774
# Epoch 2 Batch 1100 Loss 0.5232
# Epoch 2 Batch 1200 Loss 0.5120
# Epoch 2 Batch 1249 Loss 0.6298
# Epoch 3 Batch 0 Loss 0.2989
# Epoch 3 Batch 100 Loss 0.3581
# Epoch 3 Batch 200 Loss 0.3855
# Epoch 3 Batch 300 Loss 0.3397
# Epoch 3 Batch 400 Loss 0.2842
# Epoch 3 Batch 500 Loss 0.2836
# Epoch 3 Batch 600 Loss 0.3661
# Epoch 3 Batch 700 Loss 0.3683
# Epoch 3 Batch 800 Loss 0.3371
# Epoch 3 Batch 900 Loss 0.4168
# Epoch 3 Batch 1000 Loss 0.3386
# Epoch 3 Batch 1100 Loss 0.4246
# Epoch 3 Batch 1200 Loss 0.2816
# Epoch 3 Batch 1249 Loss 0.3273
# Epoch 4 Batch 0 Loss 0.1988
# Epoch 4 Batch 100 Loss 0.1842
# Epoch 4 Batch 200 Loss 0.1697
# Epoch 4 Batch 300 Loss 0.1888
# Epoch 4 Batch 400 Loss 0.1215
# Epoch 4 Batch 500 Loss 0.2262
# Epoch 4 Batch 600 Loss 0.1847
# Epoch 4 Batch 700 Loss 0.2008
# Epoch 4 Batch 800 Loss 0.1745
# Epoch 4 Batch 900 Loss 0.1656
# Epoch 4 Batch 1000 Loss 0.1809
# Epoch 4 Batch 1100 Loss 0.1967
# Epoch 4 Batch 1200 Loss 0.2088
# Epoch 4 Batch 1249 Loss 0.1996
# Epoch 5 Batch 0 Loss 0.0954
# Epoch 5 Batch 100 Loss 0.1642
# Epoch 5 Batch 200 Loss 0.1207
# Epoch 5 Batch 300 Loss 0.0812
# Epoch 5 Batch 400 Loss 0.1550
# Epoch 5 Batch 500 Loss 0.1787
# Epoch 5 Batch 600 Loss 0.1582
# Epoch 5 Batch 700 Loss 0.1206
# Epoch 5 Batch 800 Loss 0.1435
# Epoch 5 Batch 900 Loss 0.1173
# Epoch 5 Batch 1000 Loss 0.1767
# Epoch 5 Batch 1100 Loss 0.1624
# Epoch 5 Batch 1200 Loss 0.1791
# Epoch 5 Batch 1249 Loss 0.1415
# Epoch 6 Batch 0 Loss 0.0828
# Epoch 6 Batch 100 Loss 0.1112
# Epoch 6 Batch 200 Loss 0.0896
# Epoch 6 Batch 300 Loss 0.1121
# Epoch 6 Batch 400 Loss 0.1105
# Epoch 6 Batch 500 Loss 0.1273
# Epoch 6 Batch 600 Loss 0.1422
# Epoch 6 Batch 700 Loss 0.0907
# Epoch 6 Batch 800 Loss 0.1215
# Epoch 6 Batch 900 Loss 0.1015
# Epoch 6 Batch 1000 Loss 0.1319
# Epoch 6 Batch 1100 Loss 0.0665
# Epoch 6 Batch 1200 Loss 0.1272
# Epoch 6 Batch 1249 Loss 0.1126
# Epoch 7 Batch 0 Loss 0.0922
# Epoch 7 Batch 100 Loss 0.1092
# Epoch 7 Batch 200 Loss 0.0988
# Epoch 7 Batch 300 Loss 0.0821
# Epoch 7 Batch 400 Loss 0.0689
# Epoch 7 Batch 500 Loss 0.0874
# Epoch 7 Batch 600 Loss 0.1433
# Epoch 7 Batch 700 Loss 0.0704
# Epoch 7 Batch 800 Loss 0.1757
# Epoch 7 Batch 900 Loss 0.0859
# Epoch 7 Batch 1000 Loss 0.1353
# Epoch 7 Batch 1100 Loss 0.1101
# Epoch 7 Batch 1200 Loss 0.1235
# Epoch 7 Batch 1249 Loss 0.0977
# Epoch 8 Batch 0 Loss 0.0664
# Epoch 8 Batch 100 Loss 0.0699
# Epoch 8 Batch 200 Loss 0.0484
# Epoch 8 Batch 300 Loss 0.0739
# Epoch 8 Batch 400 Loss 0.0642
# Epoch 8 Batch 500 Loss 0.0716
# Epoch 8 Batch 600 Loss 0.1171
# Epoch 8 Batch 700 Loss 0.0669
# Epoch 8 Batch 800 Loss 0.1346
# Epoch 8 Batch 900 Loss 0.0919
# Epoch 8 Batch 1000 Loss 0.0924
# Epoch 8 Batch 1100 Loss 0.0815
# Epoch 8 Batch 1200 Loss 0.0955
# Epoch 8 Batch 1249 Loss 0.0887
# Epoch 9 Batch 0 Loss 0.0574
# Epoch 9 Batch 100 Loss 0.0933
# Epoch 9 Batch 200 Loss 0.0627
# Epoch 9 Batch 300 Loss 0.0790
# Epoch 9 Batch 400 Loss 0.0610
# Epoch 9 Batch 500 Loss 0.0974
# Epoch 9 Batch 600 Loss 0.0840
# Epoch 9 Batch 700 Loss 0.0669
# Epoch 9 Batch 800 Loss 0.1109
# Epoch 9 Batch 900 Loss 0.1105
# Epoch 9 Batch 1000 Loss 0.0830
# Epoch 9 Batch 1100 Loss 0.0996
# Epoch 9 Batch 1200 Loss 0.0678
# Epoch 9 Batch 1249 Loss 0.0829
# Epoch 10 Batch 0 Loss 0.0350
# Epoch 10 Batch 100 Loss 0.0477
# Epoch 10 Batch 200 Loss 0.0488
# Epoch 10 Batch 300 Loss 0.0682
# Epoch 10 Batch 400 Loss 0.0735
# Epoch 10 Batch 500 Loss 0.0556
# Epoch 10 Batch 600 Loss 0.0703
# Epoch 10 Batch 700 Loss 0.0800
# Epoch 10 Batch 800 Loss 0.0629
# Epoch 10 Batch 900 Loss 0.0697
# Epoch 10 Batch 1000 Loss 0.0590
# Epoch 10 Batch 1100 Loss 0.0667
# Epoch 10 Batch 1200 Loss 0.1016
# Epoch 10 Batch 1249 Loss 0.0763
# Epoch 11 Batch 0 Loss 0.0693
# Epoch 11 Batch 100 Loss 0.0748
# Epoch 11 Batch 200 Loss 0.0654
# Epoch 11 Batch 300 Loss 0.0694
# Epoch 11 Batch 400 Loss 0.0452
# Epoch 11 Batch 500 Loss 0.0778
# Epoch 11 Batch 600 Loss 0.0966
# Epoch 11 Batch 700 Loss 0.0772
# Epoch 11 Batch 800 Loss 0.1017
# Epoch 11 Batch 900 Loss 0.0850
# Epoch 11 Batch 1000 Loss 0.1213
# Epoch 11 Batch 1100 Loss 0.0769
# Epoch 11 Batch 1200 Loss 0.1145
# Epoch 11 Batch 1249 Loss 0.0739
# Epoch 12 Batch 0 Loss 0.0759
# Epoch 12 Batch 100 Loss 0.0614
# Epoch 12 Batch 200 Loss 0.0694
# Epoch 12 Batch 300 Loss 0.0638
# Epoch 12 Batch 400 Loss 0.0589
# Epoch 12 Batch 500 Loss 0.0423
# Epoch 12 Batch 600 Loss 0.0985
# Epoch 12 Batch 700 Loss 0.0825
# Epoch 12 Batch 800 Loss 0.0439
# Epoch 12 Batch 900 Loss 0.0754
# Epoch 12 Batch 1000 Loss 0.0673
# Epoch 12 Batch 1100 Loss 0.0591
# Epoch 12 Batch 1200 Loss 0.0708
# Epoch 12 Batch 1249 Loss 0.0701
# Epoch 13 Batch 0 Loss 0.0543
# Epoch 13 Batch 100 Loss 0.0395
# Epoch 13 Batch 200 Loss 0.0700
# Epoch 13 Batch 300 Loss 0.0640
# Epoch 13 Batch 400 Loss 0.0429
# Epoch 13 Batch 500 Loss 0.0458
# Epoch 13 Batch 600 Loss 0.0586
# Epoch 13 Batch 700 Loss 0.0833
# Epoch 13 Batch 800 Loss 0.0706
# Epoch 13 Batch 900 Loss 0.0564
# Epoch 13 Batch 1000 Loss 0.0789
# Epoch 13 Batch 1100 Loss 0.0571
# Epoch 13 Batch 1200 Loss 0.0519
# Epoch 13 Batch 1249 Loss 0.0674
# Epoch 14 Batch 0 Loss 0.0805
# Epoch 14 Batch 100 Loss 0.0537
# Epoch 14 Batch 200 Loss 0.0558
# Epoch 14 Batch 300 Loss 0.0645
# Epoch 14 Batch 400 Loss 0.0591
# Epoch 14 Batch 500 Loss 0.0400
# Epoch 14 Batch 600 Loss 0.0428
# Epoch 14 Batch 700 Loss 0.0577
# Epoch 14 Batch 800 Loss 0.0700
# Epoch 14 Batch 900 Loss 0.0621
# Epoch 14 Batch 1000 Loss 0.0507
# Epoch 14 Batch 1100 Loss 0.0475
# Epoch 14 Batch 1200 Loss 0.0658
# Epoch 14 Batch 1249 Loss 0.0654
# Epoch 15 Batch 0 Loss 0.0415
# Epoch 15 Batch 100 Loss 0.0635
# Epoch 15 Batch 200 Loss 0.0522
# Epoch 15 Batch 300 Loss 0.0625
# Epoch 15 Batch 400 Loss 0.0516
# Epoch 15 Batch 500 Loss 0.0658
# Epoch 15 Batch 600 Loss 0.0644
# Epoch 15 Batch 700 Loss 0.0597
# Epoch 15 Batch 800 Loss 0.0516
# Epoch 15 Batch 900 Loss 0.1108
# Epoch 15 Batch 1000 Loss 0.0826
# Epoch 15 Batch 1100 Loss 0.0456
# Epoch 15 Batch 1200 Loss 0.0662
# Epoch 15 Batch 1249 Loss 0.0625
# Epoch 16 Batch 0 Loss 0.0234
# Epoch 16 Batch 100 Loss 0.0622
# Epoch 16 Batch 200 Loss 0.0545
# Epoch 16 Batch 300 Loss 0.0698
# Epoch 16 Batch 400 Loss 0.0535
# Epoch 16 Batch 500 Loss 0.0571
# Epoch 16 Batch 600 Loss 0.0512
# Epoch 16 Batch 700 Loss 0.0595
# Epoch 16 Batch 800 Loss 0.0916
# Epoch 16 Batch 900 Loss 0.0390
# Epoch 16 Batch 1000 Loss 0.0594
# Epoch 16 Batch 1100 Loss 0.0360
# Epoch 16 Batch 1200 Loss 0.0792
# Epoch 16 Batch 1249 Loss 0.0612
# Epoch 17 Batch 0 Loss 0.0556
# Epoch 17 Batch 100 Loss 0.0597
# Epoch 17 Batch 200 Loss 0.0556
# Epoch 17 Batch 300 Loss 0.0557
# Epoch 17 Batch 400 Loss 0.0571
# Epoch 17 Batch 500 Loss 0.0494
# Epoch 17 Batch 600 Loss 0.0587
# Epoch 17 Batch 700 Loss 0.0933
# Epoch 17 Batch 800 Loss 0.0403
# Epoch 17 Batch 900 Loss 0.0588
# Epoch 17 Batch 1000 Loss 0.0186
# Epoch 17 Batch 1100 Loss 0.0630
# Epoch 17 Batch 1200 Loss 0.0506
# Epoch 17 Batch 1249 Loss 0.0595
# Epoch 18 Batch 0 Loss 0.0567
# Epoch 18 Batch 100 Loss 0.0517
# Epoch 18 Batch 200 Loss 0.0389
# Epoch 18 Batch 300 Loss 0.0639
# Epoch 18 Batch 400 Loss 0.0734
# Epoch 18 Batch 500 Loss 0.0436
# Epoch 18 Batch 600 Loss 0.0622
# Epoch 18 Batch 700 Loss 0.0662
# Epoch 18 Batch 800 Loss 0.0554
# Epoch 18 Batch 900 Loss 0.0686
# Epoch 18 Batch 1000 Loss 0.0973
# Epoch 18 Batch 1100 Loss 0.0933
# Epoch 18 Batch 1200 Loss 0.0864
# Epoch 18 Batch 1249 Loss 0.0581
# Epoch 19 Batch 0 Loss 0.0575
# Epoch 19 Batch 100 Loss 0.0370
# Epoch 19 Batch 200 Loss 0.0387
# Epoch 19 Batch 300 Loss 0.0578
# Epoch 19 Batch 400 Loss 0.0601
# Epoch 19 Batch 500 Loss 0.0592
# Epoch 19 Batch 600 Loss 0.0607
# Epoch 19 Batch 700 Loss 0.0639
# Epoch 19 Batch 800 Loss 0.0634
# Epoch 19 Batch 900 Loss 0.0935
# Epoch 19 Batch 1000 Loss 0.0840
# Epoch 19 Batch 1100 Loss 0.0332
# Epoch 19 Batch 1200 Loss 0.0543
# Epoch 19 Batch 1249 Loss 0.0557
# Epoch 20 Batch 0 Loss 0.0710
# Epoch 20 Batch 100 Loss 0.0640
# Epoch 20 Batch 200 Loss 0.0392
# Epoch 20 Batch 300 Loss 0.0727
# Epoch 20 Batch 400 Loss 0.0628
# Epoch 20 Batch 500 Loss 0.0531
# Epoch 20 Batch 600 Loss 0.0288
# Epoch 20 Batch 700 Loss 0.0724
# Epoch 20 Batch 800 Loss 0.0821
# Epoch 20 Batch 900 Loss 0.0485
# Epoch 20 Batch 1000 Loss 0.0915
# Epoch 20 Batch 1100 Loss 0.0474
# Epoch 20 Batch 1200 Loss 0.0773
# Epoch 20 Batch 1249 Loss 0.0546
# Epoch 21 Batch 0 Loss 0.0640
# Epoch 21 Batch 100 Loss 0.0468
# Epoch 21 Batch 200 Loss 0.0256
# Epoch 21 Batch 300 Loss 0.0462
# Epoch 21 Batch 400 Loss 0.0498
# Epoch 21 Batch 500 Loss 0.0594
# Epoch 21 Batch 600 Loss 0.0702
# Epoch 21 Batch 700 Loss 0.0921
# Epoch 21 Batch 800 Loss 0.0561
# Epoch 21 Batch 900 Loss 0.0739
# Epoch 21 Batch 1000 Loss 0.0496
# Epoch 21 Batch 1100 Loss 0.0806
# Epoch 21 Batch 1200 Loss 0.0719
# Epoch 21 Batch 1249 Loss 0.0543
# Epoch 22 Batch 0 Loss 0.0366
# Epoch 22 Batch 100 Loss 0.0492
# Epoch 22 Batch 200 Loss 0.0324
# Epoch 22 Batch 300 Loss 0.0547
# Epoch 22 Batch 400 Loss 0.0336
# Epoch 22 Batch 500 Loss 0.0342
# Epoch 22 Batch 600 Loss 0.0337
# Epoch 22 Batch 700 Loss 0.0515
# Epoch 22 Batch 800 Loss 0.0582
# Epoch 22 Batch 900 Loss 0.0673
# Epoch 22 Batch 1000 Loss 0.0705
# Epoch 22 Batch 1100 Loss 0.0930
# Epoch 22 Batch 1200 Loss 0.0583
# Epoch 22 Batch 1249 Loss 0.0527
# Epoch 23 Batch 0 Loss 0.0354
# Epoch 23 Batch 100 Loss 0.0639
# Epoch 23 Batch 200 Loss 0.0489
# Epoch 23 Batch 300 Loss 0.0321
# Epoch 23 Batch 400 Loss 0.0176
# Epoch 23 Batch 500 Loss 0.0591
# Epoch 23 Batch 600 Loss 0.0431
# Epoch 23 Batch 700 Loss 0.0730
# Epoch 23 Batch 800 Loss 0.0734
# Epoch 23 Batch 900 Loss 0.0531
# Epoch 23 Batch 1000 Loss 0.0677
# Epoch 23 Batch 1100 Loss 0.0491
# Epoch 23 Batch 1200 Loss 0.0707
# Epoch 23 Batch 1249 Loss 0.0518
# Epoch 24 Batch 0 Loss 0.0173
# Epoch 24 Batch 100 Loss 0.0502
# Epoch 24 Batch 200 Loss 0.0155
# Epoch 24 Batch 300 Loss 0.0618
# Epoch 24 Batch 400 Loss 0.0572
# Epoch 24 Batch 500 Loss 0.0453
# Epoch 24 Batch 600 Loss 0.0355
# Epoch 24 Batch 700 Loss 0.0370
# Epoch 24 Batch 800 Loss 0.0455
# Epoch 24 Batch 900 Loss 0.0904
# Epoch 24 Batch 1000 Loss 0.0639
# Epoch 24 Batch 1100 Loss 0.0556
# Epoch 24 Batch 1200 Loss 0.0727
# Epoch 24 Batch 1249 Loss 0.0507
# Epoch 25 Batch 0 Loss 0.0474
# Epoch 25 Batch 100 Loss 0.0693
# Epoch 25 Batch 200 Loss 0.0457
# Epoch 25 Batch 300 Loss 0.0304
# Epoch 25 Batch 400 Loss 0.0582
# Epoch 25 Batch 500 Loss 0.0540
# Epoch 25 Batch 600 Loss 0.0468
# Epoch 25 Batch 700 Loss 0.0499
# Epoch 25 Batch 800 Loss 0.0400
# Epoch 25 Batch 900 Loss 0.0365
# Epoch 25 Batch 1000 Loss 0.0531
# Epoch 25 Batch 1100 Loss 0.0401
# Epoch 25 Batch 1200 Loss 0.0647
# Epoch 25 Batch 1249 Loss 0.0496
# Epoch 26 Batch 0 Loss 0.0398
# Epoch 26 Batch 100 Loss 0.0354
# Epoch 26 Batch 200 Loss 0.0530
# Epoch 26 Batch 300 Loss 0.0384
# Epoch 26 Batch 400 Loss 0.0205
# Epoch 26 Batch 500 Loss 0.0463
# Epoch 26 Batch 600 Loss 0.0610
# Epoch 26 Batch 700 Loss 0.0773
# Epoch 26 Batch 800 Loss 0.0530
# Epoch 26 Batch 900 Loss 0.0581
# Epoch 26 Batch 1000 Loss 0.0514
# Epoch 26 Batch 1100 Loss 0.0690
# Epoch 26 Batch 1200 Loss 0.0365
# Epoch 26 Batch 1249 Loss 0.0492
# Epoch 27 Batch 0 Loss 0.0397
# Epoch 27 Batch 100 Loss 0.0527
# Epoch 27 Batch 200 Loss 0.0355
# Epoch 27 Batch 300 Loss 0.0532
# Epoch 27 Batch 400 Loss 0.0340
# Epoch 27 Batch 500 Loss 0.0355
# Epoch 27 Batch 600 Loss 0.0706
# Epoch 27 Batch 700 Loss 0.0601
# Epoch 27 Batch 800 Loss 0.0424
# Epoch 27 Batch 900 Loss 0.0547
# Epoch 27 Batch 1000 Loss 0.0563
# Epoch 27 Batch 1100 Loss 0.0705
# Epoch 27 Batch 1200 Loss 0.0369
# Epoch 27 Batch 1249 Loss 0.0484
# Epoch 28 Batch 0 Loss 0.0321
# Epoch 28 Batch 100 Loss 0.0445
# Epoch 28 Batch 200 Loss 0.0626
# Epoch 28 Batch 300 Loss 0.0474
# Epoch 28 Batch 400 Loss 0.0311
# Epoch 28 Batch 500 Loss 0.0430
# Epoch 28 Batch 600 Loss 0.0370
# Epoch 28 Batch 700 Loss 0.0508
# Epoch 28 Batch 800 Loss 0.0587
# Epoch 28 Batch 900 Loss 0.0638
# Epoch 28 Batch 1000 Loss 0.0707
# Epoch 28 Batch 1100 Loss 0.0839
# Epoch 28 Batch 1200 Loss 0.0389
# Epoch 28 Batch 1249 Loss 0.0479
# Epoch 29 Batch 0 Loss 0.0297
# Epoch 29 Batch 100 Loss 0.0329
# Epoch 29 Batch 200 Loss 0.0305
# Epoch 29 Batch 300 Loss 0.0491
# Epoch 29 Batch 400 Loss 0.0305
# Epoch 29 Batch 500 Loss 0.0636
# Epoch 29 Batch 600 Loss 0.0415
# Epoch 29 Batch 700 Loss 0.0392
# Epoch 29 Batch 800 Loss 0.0671
# Epoch 29 Batch 900 Loss 0.0333
# Epoch 29 Batch 1000 Loss 0.0536
# Epoch 29 Batch 1100 Loss 0.0615
# Epoch 29 Batch 1200 Loss 0.0446
# Epoch 29 Batch 1249 Loss 0.0470
# Epoch 30 Batch 0 Loss 0.0412
# Epoch 30 Batch 100 Loss 0.0298
# Epoch 30 Batch 200 Loss 0.0669
# Epoch 30 Batch 300 Loss 0.0215
# Epoch 30 Batch 400 Loss 0.0404
# Epoch 30 Batch 500 Loss 0.0495
# Epoch 30 Batch 600 Loss 0.0486
# Epoch 30 Batch 700 Loss 0.0572
# Epoch 30 Batch 800 Loss 0.0758
# Epoch 30 Batch 900 Loss 0.0320
# Epoch 30 Batch 1000 Loss 0.0415
# Epoch 30 Batch 1100 Loss 0.0612
# Epoch 30 Batch 1200 Loss 0.0681
# Epoch 30 Batch 1249 Loss 0.0466
# Epoch 31 Batch 0 Loss 0.0399
# Epoch 31 Batch 100 Loss 0.0375
# Epoch 31 Batch 200 Loss 0.0267
# Epoch 31 Batch 300 Loss 0.0675
# Epoch 31 Batch 400 Loss 0.0323
# Epoch 31 Batch 500 Loss 0.0495
# Epoch 31 Batch 600 Loss 0.0549
# Epoch 31 Batch 700 Loss 0.0358
# Epoch 31 Batch 800 Loss 0.0495
# Epoch 31 Batch 900 Loss 0.0529
# Epoch 31 Batch 1000 Loss 0.0412
# Epoch 31 Batch 1100 Loss 0.0976
# Epoch 31 Batch 1200 Loss 0.0468
# Epoch 31 Batch 1249 Loss 0.0456
# Epoch 32 Batch 0 Loss 0.0251
# Epoch 32 Batch 100 Loss 0.0452
# Epoch 32 Batch 200 Loss 0.0549
# Epoch 32 Batch 300 Loss 0.0367
# Epoch 32 Batch 400 Loss 0.0318
# Epoch 32 Batch 500 Loss 0.0283
# Epoch 32 Batch 600 Loss 0.0776
# Epoch 32 Batch 700 Loss 0.0437
# Epoch 32 Batch 800 Loss 0.0485
# Epoch 32 Batch 900 Loss 0.0360
# Epoch 32 Batch 1000 Loss 0.0806
# Epoch 32 Batch 1100 Loss 0.0450
# Epoch 32 Batch 1200 Loss 0.0475
# Epoch 32 Batch 1249 Loss 0.0459
# Epoch 33 Batch 0 Loss 0.0376
# Epoch 33 Batch 100 Loss 0.0429
# Epoch 33 Batch 200 Loss 0.0380
# Epoch 33 Batch 300 Loss 0.0562
# Epoch 33 Batch 400 Loss 0.0735
# Epoch 33 Batch 500 Loss 0.0771
# Epoch 33 Batch 600 Loss 0.0370
# Epoch 33 Batch 700 Loss 0.0541
# Epoch 33 Batch 800 Loss 0.0356
# Epoch 33 Batch 900 Loss 0.0336
# Epoch 33 Batch 1000 Loss 0.0751
# Epoch 33 Batch 1100 Loss 0.0567
# Epoch 33 Batch 1200 Loss 0.0601
# Epoch 33 Batch 1249 Loss 0.0453
# Epoch 34 Batch 0 Loss 0.0455
# Epoch 34 Batch 100 Loss 0.0655
# Epoch 34 Batch 200 Loss 0.0557
# Epoch 34 Batch 300 Loss 0.0331
# Epoch 34 Batch 400 Loss 0.0382
# Epoch 34 Batch 500 Loss 0.0114
# Epoch 34 Batch 600 Loss 0.0522
# Epoch 34 Batch 700 Loss 0.0489
# Epoch 34 Batch 800 Loss 0.0835
# Epoch 34 Batch 900 Loss 0.0294
# Epoch 34 Batch 1000 Loss 0.0672
# Epoch 34 Batch 1100 Loss 0.0498
# Epoch 34 Batch 1200 Loss 0.0671
# Epoch 34 Batch 1249 Loss 0.0443
# Epoch 35 Batch 0 Loss 0.0361
# Epoch 35 Batch 100 Loss 0.0161
# Epoch 35 Batch 200 Loss 0.0414
# Epoch 35 Batch 300 Loss 0.0478
# Epoch 35 Batch 400 Loss 0.0338
# Epoch 35 Batch 500 Loss 0.0654
# Epoch 35 Batch 600 Loss 0.0479
# Epoch 35 Batch 700 Loss 0.0589
# Epoch 35 Batch 800 Loss 0.0750
# Epoch 35 Batch 900 Loss 0.0691
# Epoch 35 Batch 1000 Loss 0.0267
# Epoch 35 Batch 1100 Loss 0.0707
# Epoch 35 Batch 1200 Loss 0.0449
# Epoch 35 Batch 1249 Loss 0.0441
# Epoch 36 Batch 0 Loss 0.0290
# Epoch 36 Batch 100 Loss 0.0482
# Epoch 36 Batch 200 Loss 0.0335
# Epoch 36 Batch 300 Loss 0.0466
# Epoch 36 Batch 400 Loss 0.0327
# Epoch 36 Batch 500 Loss 0.0302
# Epoch 36 Batch 600 Loss 0.0609
# Epoch 36 Batch 700 Loss 0.0439
# Epoch 36 Batch 800 Loss 0.0388
# Epoch 36 Batch 900 Loss 0.0600
# Epoch 36 Batch 1000 Loss 0.0428
# Epoch 36 Batch 1100 Loss 0.0546
# Epoch 36 Batch 1200 Loss 0.0560
# Epoch 36 Batch 1249 Loss 0.0434
# Epoch 37 Batch 0 Loss 0.0465
# Epoch 37 Batch 100 Loss 0.0293
# Epoch 37 Batch 200 Loss 0.0276
# Epoch 37 Batch 300 Loss 0.0369
# Epoch 37 Batch 400 Loss 0.0355
# Epoch 37 Batch 500 Loss 0.0385
# Epoch 37 Batch 600 Loss 0.0448
# Epoch 37 Batch 700 Loss 0.0261
# Epoch 37 Batch 800 Loss 0.0679
# Epoch 37 Batch 900 Loss 0.0476
# Epoch 37 Batch 1000 Loss 0.0540
# Epoch 37 Batch 1100 Loss 0.0460
# Epoch 37 Batch 1200 Loss 0.0591
# Epoch 37 Batch 1249 Loss 0.0435
# Epoch 38 Batch 0 Loss 0.0361
# Epoch 38 Batch 100 Loss 0.0305
# Epoch 38 Batch 200 Loss 0.0316
# Epoch 38 Batch 300 Loss 0.0506
# Epoch 38 Batch 400 Loss 0.0209
# Epoch 38 Batch 500 Loss 0.0294
# Epoch 38 Batch 600 Loss 0.0296
# Epoch 38 Batch 700 Loss 0.0620
# Epoch 38 Batch 800 Loss 0.0607
# Epoch 38 Batch 900 Loss 0.0542
# Epoch 38 Batch 1000 Loss 0.0585
# Epoch 38 Batch 1100 Loss 0.0520
# Epoch 38 Batch 1200 Loss 0.0381
# Epoch 38 Batch 1249 Loss 0.0426
# Epoch 39 Batch 0 Loss 0.0170
# Epoch 39 Batch 100 Loss 0.0396
# Epoch 39 Batch 200 Loss 0.0243
# Epoch 39 Batch 300 Loss 0.0168
# Epoch 39 Batch 400 Loss 0.0914
# Epoch 39 Batch 500 Loss 0.0246
# Epoch 39 Batch 600 Loss 0.0314
# Epoch 39 Batch 700 Loss 0.0208
# Epoch 39 Batch 800 Loss 0.0441
# Epoch 39 Batch 900 Loss 0.0529
# Epoch 39 Batch 1000 Loss 0.0387
# Epoch 39 Batch 1100 Loss 0.0637
# Epoch 39 Batch 1200 Loss 0.0477
# Epoch 39 Batch 1249 Loss 0.0435
# Epoch 40 Batch 0 Loss 0.0255
# Epoch 40 Batch 100 Loss 0.0294
# Epoch 40 Batch 200 Loss 0.0335
# Epoch 40 Batch 300 Loss 0.0498
# Epoch 40 Batch 400 Loss 0.0337
# Epoch 40 Batch 500 Loss 0.0341
# Epoch 40 Batch 600 Loss 0.0408
# Epoch 40 Batch 700 Loss 0.0190
# Epoch 40 Batch 800 Loss 0.0473
# Epoch 40 Batch 900 Loss 0.0497
# Epoch 40 Batch 1000 Loss 0.0486
# Epoch 40 Batch 1100 Loss 0.0569
# Epoch 40 Batch 1200 Loss 0.0532
# Epoch 40 Batch 1249 Loss 0.0421
# Epoch 41 Batch 0 Loss 0.0258
# Epoch 41 Batch 100 Loss 0.0370
# Epoch 41 Batch 200 Loss 0.0397
# Epoch 41 Batch 300 Loss 0.0411
# Epoch 41 Batch 400 Loss 0.0340
# Epoch 41 Batch 500 Loss 0.0344
# Epoch 41 Batch 600 Loss 0.0469
# Epoch 41 Batch 700 Loss 0.0416
# Epoch 41 Batch 800 Loss 0.0475
# Epoch 41 Batch 900 Loss 0.0394
# Epoch 41 Batch 1000 Loss 0.0507
# Epoch 41 Batch 1100 Loss 0.0774
# Epoch 41 Batch 1200 Loss 0.0658
# Epoch 41 Batch 1249 Loss 0.0416
# Epoch 42 Batch 0 Loss 0.0215
# Epoch 42 Batch 100 Loss 0.0489
# Epoch 42 Batch 200 Loss 0.0479
# Epoch 42 Batch 300 Loss 0.0435
# Epoch 42 Batch 400 Loss 0.0549
# Epoch 42 Batch 500 Loss 0.0300
# Epoch 42 Batch 600 Loss 0.0445
# Epoch 42 Batch 700 Loss 0.0316
# Epoch 42 Batch 800 Loss 0.0478
# Epoch 42 Batch 900 Loss 0.0522
# Epoch 42 Batch 1000 Loss 0.0642
# Epoch 42 Batch 1100 Loss 0.0500
# Epoch 42 Batch 1200 Loss 0.0400
# Epoch 42 Batch 1249 Loss 0.0417
# Epoch 43 Batch 0 Loss 0.0242
# Epoch 43 Batch 100 Loss 0.0454
# Epoch 43 Batch 200 Loss 0.0644
# Epoch 43 Batch 300 Loss 0.0334
# Epoch 43 Batch 400 Loss 0.0379
# Epoch 43 Batch 500 Loss 0.0407
# Epoch 43 Batch 600 Loss 0.0601
# Epoch 43 Batch 700 Loss 0.0464
# Epoch 43 Batch 800 Loss 0.0516
# Epoch 43 Batch 900 Loss 0.0533
# Epoch 43 Batch 1000 Loss 0.0355
# Epoch 43 Batch 1100 Loss 0.0596
# Epoch 43 Batch 1200 Loss 0.0390
# Epoch 43 Batch 1249 Loss 0.0415
# Epoch 44 Batch 0 Loss 0.0263
# Epoch 44 Batch 100 Loss 0.0348
# Epoch 44 Batch 200 Loss 0.0250
# Epoch 44 Batch 300 Loss 0.0446
# Epoch 44 Batch 400 Loss 0.0349
# Epoch 44 Batch 500 Loss 0.0345
# Epoch 44 Batch 600 Loss 0.0446
# Epoch 44 Batch 700 Loss 0.0260
# Epoch 44 Batch 800 Loss 0.0685
# Epoch 44 Batch 900 Loss 0.0310
# Epoch 44 Batch 1000 Loss 0.0655
# Epoch 44 Batch 1100 Loss 0.0445
# Epoch 44 Batch 1200 Loss 0.0492
# Epoch 44 Batch 1249 Loss 0.0406
# Epoch 45 Batch 0 Loss 0.0241
# Epoch 45 Batch 100 Loss 0.0249
# Epoch 45 Batch 200 Loss 0.0521
# Epoch 45 Batch 300 Loss 0.0456
# Epoch 45 Batch 400 Loss 0.0277
# Epoch 45 Batch 500 Loss 0.0488
# Epoch 45 Batch 600 Loss 0.0610
# Epoch 45 Batch 700 Loss 0.0520
# Epoch 45 Batch 800 Loss 0.0466
# Epoch 45 Batch 900 Loss 0.0379
# Epoch 45 Batch 1000 Loss 0.0620
# Epoch 45 Batch 1100 Loss 0.0550
# Epoch 45 Batch 1200 Loss 0.0185
# Epoch 45 Batch 1249 Loss 0.0412
# Epoch 46 Batch 0 Loss 0.0250
# Epoch 46 Batch 100 Loss 0.0141
# Epoch 46 Batch 200 Loss 0.0249
# Epoch 46 Batch 300 Loss 0.0264
# Epoch 46 Batch 400 Loss 0.0438
# Epoch 46 Batch 500 Loss 0.0388
# Epoch 46 Batch 600 Loss 0.0372
# Epoch 46 Batch 700 Loss 0.0727
# Epoch 46 Batch 800 Loss 0.0449
# Epoch 46 Batch 900 Loss 0.0338
# Epoch 46 Batch 1000 Loss 0.0407
# Epoch 46 Batch 1100 Loss 0.0302
# Epoch 46 Batch 1200 Loss 0.0705
# Epoch 46 Batch 1249 Loss 0.0405
# Epoch 47 Batch 0 Loss 0.0322
# Epoch 47 Batch 100 Loss 0.0203
# Epoch 47 Batch 200 Loss 0.0449
# Epoch 47 Batch 300 Loss 0.0287
# Epoch 47 Batch 400 Loss 0.0473
# Epoch 47 Batch 500 Loss 0.0575
# Epoch 47 Batch 600 Loss 0.0531
# Epoch 47 Batch 700 Loss 0.0415
# Epoch 47 Batch 800 Loss 0.0223
# Epoch 47 Batch 900 Loss 0.0404
# Epoch 47 Batch 1000 Loss 0.0462
# Epoch 47 Batch 1100 Loss 0.0344
# Epoch 47 Batch 1200 Loss 0.0251
# Epoch 47 Batch 1249 Loss 0.0408
# Epoch 48 Batch 0 Loss 0.0406
# Epoch 48 Batch 100 Loss 0.0329
# Epoch 48 Batch 200 Loss 0.0299
# Epoch 48 Batch 300 Loss 0.0340
# Epoch 48 Batch 400 Loss 0.0392
# Epoch 48 Batch 500 Loss 0.0288
# Epoch 48 Batch 600 Loss 0.0497
# Epoch 48 Batch 700 Loss 0.0478
# Epoch 48 Batch 800 Loss 0.0436
# Epoch 48 Batch 900 Loss 0.0321
# Epoch 48 Batch 1000 Loss 0.0360
# Epoch 48 Batch 1100 Loss 0.0525
# Epoch 48 Batch 1200 Loss 0.0569
# Epoch 48 Batch 1249 Loss 0.0401
# Epoch 49 Batch 0 Loss 0.0266
# Epoch 49 Batch 100 Loss 0.0284
# Epoch 49 Batch 200 Loss 0.0269
# Epoch 49 Batch 300 Loss 0.0263
# Epoch 49 Batch 400 Loss 0.0183
# Epoch 49 Batch 500 Loss 0.0325
# Epoch 49 Batch 600 Loss 0.0306
# Epoch 49 Batch 700 Loss 0.0263
# Epoch 49 Batch 800 Loss 0.0409
# Epoch 49 Batch 900 Loss 0.0371
# Epoch 49 Batch 1000 Loss 0.0675
# Epoch 49 Batch 1100 Loss 0.0504
# Epoch 49 Batch 1200 Loss 0.0322
# Epoch 49 Batch 1249 Loss 0.0403
# Epoch 50 Batch 0 Loss 0.0237
# Epoch 50 Batch 100 Loss 0.0373
# Epoch 50 Batch 200 Loss 0.0275
# Epoch 50 Batch 300 Loss 0.0348
# Epoch 50 Batch 400 Loss 0.0285
# Epoch 50 Batch 500 Loss 0.0237
# Epoch 50 Batch 600 Loss 0.0393
# Epoch 50 Batch 700 Loss 0.0420
# Epoch 50 Batch 800 Loss 0.0391
# Epoch 50 Batch 900 Loss 0.0327
# Epoch 50 Batch 1000 Loss 0.0595
# Epoch 50 Batch 1100 Loss 0.0240
# Epoch 50 Batch 1200 Loss 0.0489
# Epoch 50 Batch 1249 Loss 0.0394

# %% [markdown]
# Функция перевода на основании предикта

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [input_lang_tokenizer.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs], maxlen=max_length_inp, padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, UNITS))]

  enc_out, enc_hidden = encoder(inputs, hidden)
  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([target_lang_tokenizer.word_index['<start>']], 0)

  for t in range(max_length_targ):

    predictions, dec_hidden, attention_weights = decoder(dec_input, dec_hidden, enc_out)

    if WITH_ATTENTION:
      # storing the attention weights to plot later on
      attention_weights = tf.reshape(attention_weights, (-1, ))
      attention_plot[t] = attention_weights.numpy()

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += target_lang_tokenizer.index_word[predicted_id] + ' '

    if target_lang_tokenizer.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(sentence):

  result, sentence, attention_plot = evaluate(sentence)

  if WITH_ATTENTION:
    attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
    plot_attention(attention_plot, sentence.split(' '), result.split(' '))

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %% [markdown]
# Проверка перевода

# %%
translate('Всё будет хорошо')
# Out:
# Input: <start> всё будет хорошо <end>
# Predicted translation: will be fine . <end>

# %%
translate('Вы еще дома?')
# Out:
# Input: <start> вы еще дома ? <end>
# Predicted translation: are you still at home ? <end>

# %% [markdown]
# #### Перевод с помощью трансформера

# %% [markdown]
# Текст для перевода

# %%
text = \
"""
Белеет парус одинокой
В тумане моря голубом!..
Что ищет он в стране далекой?
Что кинул он в краю родном?..

Играют волны — ветер свищет,
И мачта гнется и скрипит…
Увы! он счастия не ищет
И не от счастия бежит!

Под ним струя светлей лазури,
Над ним луч солнца золотой…
А он, мятежный, просит бури,
Как будто в бурях есть покой!
"""

# %%
# %%capture
# !pip install transformers[sentencepiece]
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# %% [markdown]
# Инициализация токенайзера и модели трансформера

# %%
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-ru-en")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-ru-en")
# Out:
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/803k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading:   0%|          | 0.00/307M [00:00<?, ?B/s]

# %% [markdown]
# Инициализация пайплайна в режиме перевода

# %%
translator_ru_en = pipeline("translation", model=model, tokenizer=tokenizer, device=0)

# %% [markdown]
# Перевод

# %%
translation = translator_ru_en(text)[0]['translation_text']
translation
# Out:
# "What is he looking for in the land of the faraway? What did he throw at the edge of his native country?... the waves are playing, the wind is whistling, and the mast is racing and squeaking... alas! he's not looking for happiness and he's not running for happiness! He's got a stream of light lasuries and a sunshine of gold over him... and he, the rebel, is asking for storms as if there was peace in the storms!"

# %% [markdown]
# *По непонятной для меня причине не перевелись первые две строчки стихотворения*

# %% [markdown]
# Обратный перевод

# %%
tokenizer1 = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-ru")
model1 = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-ru")
translator_en_ru = pipeline('translation', model=model1, tokenizer=tokenizer1, device=0)
# Out:
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/803k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading:   0%|          | 0.00/307M [00:00<?, ?B/s]

# %%
back_translation = translator_en_ru(translation)[0]['translation_text']
back_translation
# Out:
# 'Что он ищет в стране далекой? он не ищет счастья и не бежит к счастью! у него есть поток светлых ласеров и золотых солнечных лучей над ним... и он, мятежник, просит штормов, как если бы в штормах был мир!'

# %% [markdown]
# *И снова часть текста была проигнорирована моделью. Хотя текст, который был переведён моделью очень схож по смыслу с оригиналом.*
